# %% [markdown]
# # Part 1: Data preprocessing

# %% [markdown]
# dataset: https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho

# %% [markdown]
# 1. Importing the libraries
# 2. Importing the dataset
# 3. Dealing with missing data
# 4. Encoding categorical variables
# 5. Splitting the dataset into train and test set
# 6. Feature scaling

# %% [markdown]
# ## Importing the libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/car data.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
dataset.shape
# Out:
# (301, 9)

# %%
# check the columns
dataset.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# information about the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# columns with categorical values
dataset.select_dtypes(include=['object']).columns
# Out:
# Index(['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission'], dtype='object')

# %%
len(dataset.select_dtypes(include=['object']).columns)
# Out:
# 4

# %%
# columns with numerical values
dataset.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner'], dtype='object')

# %%
len(dataset.select_dtypes(include=['int64', 'float64']).columns)
# Out:
# 5

# %%
# statistical summary
dataset.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ## Dealing with the missing data

# %%
# check if there are any null values
dataset.isnull().values.any()
# Out:
# False

# %%
# check how many null values
dataset.isnull().values.sum()
# Out:
# 0

# %%
# show the null values using the heatmap
plt.figure(figsize=(16,9))
sns.heatmap(dataset.isnull(), cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Encoding the categorical data

# %%
dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
dataset.shape
# Out:
# (301, 9)

# %%
# check the number of unique values in each column
print(dataset['Car_Name'].nunique())
print(dataset['Fuel_Type'].nunique())
print(dataset['Seller_Type'].nunique())
print(dataset['Transmission'].nunique())
print(dataset['Owner'].nunique())
# Out:
# 98
# 3
# 2
# 2
# 3

# %%
# final dataset
dataset = dataset.drop(columns='Car_Name')

# %%
dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Seller_Type Transmission Owner
# 0  2014           3.35           5.59  ...       Dealer       Manual     0
# 1  2013           4.75           9.54  ...       Dealer       Manual     0
# 2  2017           7.25           9.85  ...       Dealer       Manual     0
# 3  2011           2.85           4.15  ...       Dealer       Manual     0
# 4  2014           4.60           6.87  ...       Dealer       Manual     0
#
# [5 rows x 8 columns]

# %%
# add a column as current year
dataset['Current Year']=2020

# %%
dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Transmission Owner Current Year
# 0  2014           3.35           5.59  ...        Manual     0         2020
# 1  2013           4.75           9.54  ...        Manual     0         2020
# 2  2017           7.25           9.85  ...        Manual     0         2020
# 3  2011           2.85           4.15  ...        Manual     0         2020
# 4  2014           4.60           6.87  ...        Manual     0         2020
#
# [5 rows x 9 columns]

# %%
dataset['years_old'] = dataset['Current Year'] - dataset['Year']

# %%
dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Owner Current Year years_old
# 0  2014           3.35           5.59  ...      0         2020         6
# 1  2013           4.75           9.54  ...      0         2020         7
# 2  2017           7.25           9.85  ...      0         2020         3
# 3  2011           2.85           4.15  ...      0         2020         9
# 4  2014           4.60           6.87  ...      0         2020         6
#
# [5 rows x 10 columns]

# %%
dataset = dataset.drop(columns=['Year', 'Current Year'])

# %%
dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  ... Transmission Owner years_old
# 0           3.35           5.59       27000  ...       Manual     0         6
# 1           4.75           9.54       43000  ...       Manual     0         7
# 2           7.25           9.85        6900  ...       Manual     0         3
# 3           2.85           4.15        5200  ...       Manual     0         9
# 4           4.60           6.87       42450  ...       Manual     0         6
#
# [5 rows x 8 columns]

# %%
dataset = pd.get_dummies(data=dataset, drop_first=True)

# %%
dataset.head()
# Out:
#    Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0           3.35           5.59  ...                       0                    1
# 1           4.75           9.54  ...                       0                    1
# 2           7.25           9.85  ...                       0                    1
# 3           2.85           4.15  ...                       0                    1
# 4           4.60           6.87  ...                       0                    1
#
# [5 rows x 9 columns]

# %%
dataset.shape
# Out:
# (301, 9)

# %% [markdown]
# ## Correlation matrix and Heatmap

# %%
dataset_2 = dataset.drop(columns='Selling_Price')

# %%
dataset_2.corrwith(dataset['Selling_Price']).plot.bar(
    figsize=(16,9), title = 'Correlation with charges', 
    rot = 45, grid = True
)

# %%
# Create Correlation Matrix
corr = dataset.corr()

# %%
# correlation matrix
plt.figure(figsize=(16,9))
sns.heatmap(corr, annot=True)

# %% [markdown]
# ## Splitting the dataset into train and test set

# %%
dataset.head()
# Out:
#    Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0           3.35           5.59  ...                       0                    1
# 1           4.75           9.54  ...                       0                    1
# 2           7.25           9.85  ...                       0                    1
# 3           2.85           4.15  ...                       0                    1
# 4           4.60           6.87  ...                       0                    1
#
# [5 rows x 9 columns]

# %%
x = dataset.iloc[:, 1:].values

# %%
x.shape
# Out:
# (301, 8)

# %%
y = dataset.iloc[:, 0].values

# %%
y.shape
# Out:
# (301,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x_train.shape
# Out:
# (240, 8)

# %%
x_test.shape
# Out:
# (61, 8)

# %%
y_train.shape
# Out:
# (240,)

# %%
y_test.shape
# Out:
# (61,)

# %% [markdown]
# ## Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
model.feature_importances_
# Out:
# array([0.39715374, 0.04302403, 0.00047298, 0.07462333, 0.20965764,
#        0.02466723, 0.12722171, 0.12317935])

# %%
dataset.head()
# Out:
#    Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0           3.35           5.59  ...                       0                    1
# 1           4.75           9.54  ...                       0                    1
# 2           7.25           9.85  ...                       0                    1
# 3           2.85           4.15  ...                       0                    1
# 4           4.60           6.87  ...                       0                    1
#
# [5 rows x 9 columns]

# %%
dataset.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'years_old',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
index = ['Present_Price', 'Kms_Driven', 'Owner', 'years_old',
       'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
       'Transmission_Manual']

# %%
features_imps = pd.Series(model.feature_importances_, index=index)
features_imps.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# # Part 2: Building the model

# %% [markdown]
# ## 1) Multiple linear regression

# %%
# linear regression model
from sklearn.linear_model import LinearRegression
regressor_lr = LinearRegression()
regressor_lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor_lr.predict(x_test)

# %%
# np.set_printoptions(precision=2)
# print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %%
# R^2 (coefficient of determination) regression score function
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7671789069118291

# %% [markdown]
# ## 2)  Random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_rf = RandomForestRegressor()
regressor_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred = regressor_rf.predict(x_test)

# %%
# R^2 (coefficient of determination) regression score function
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8920438443227852

# %% [markdown]
# # Part 3: Fing the optimal parameters using RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters = {
    'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
    'criterion': ['mse', 'mae'],
    'max_depth': [10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10, 20, 50],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['auto', 'sqrt', 'log2']    
    }

# %%
parameters
# Out:
# {'criterion': ['mse', 'mae'],
#  'max_depth': [10, 20, 30, 40, 50],
#  'max_features': ['auto', 'sqrt', 'log2'],
#  'min_samples_leaf': [1, 2, 5, 10],
#  'min_samples_split': [2, 5, 10, 20, 50],
#  'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]}

# %%
random_forest = RandomizedSearchCV(estimator = regressor_rf, param_distributions = parameters, n_iter=10,
                                   scoring='neg_mean_absolute_error', cv = 5, verbose=2, n_jobs = 1)

# %%
random_forest.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae, total=   0.9s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae, total=   0.9s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae, total=   0.9s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae, total=   0.9s
# [CV] n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae
# [CV]  n_estimators=500, min_samples_split=5, min_samples_leaf=2, max_features=log2, max_depth=30, criterion=mae, total=   0.9s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae, total=   1.1s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae, total=   1.0s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae, total=   1.1s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae, total=   1.1s
# [CV] n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae
# [CV]  n_estimators=700, min_samples_split=20, min_samples_leaf=5, max_features=log2, max_depth=20, criterion=mae, total=   1.1s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae, total=   1.3s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae, total=   1.3s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae, total=   1.3s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae, total=   1.3s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=20, criterion=mae, total=   1.3s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse, total=   0.2s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse, total=   0.2s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse, total=   0.2s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse, total=   0.2s
# [CV] n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse
# [CV]  n_estimators=200, min_samples_split=10, min_samples_leaf=5, max_features=log2, max_depth=40, criterion=mse, total=   0.2s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=5, max_features=sqrt, max_depth=30, criterion=mse, total=   0.1s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse
# [CV]  n_estimators=900, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=30, criterion=mse, total=   1.0s
# [CV] n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae
# [CV]  n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae, total=   1.7s
# [CV] n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae
# [CV]  n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae, total=   1.7s
# [CV] n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae
# [CV]  n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae, total=   1.6s
# [CV] n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae
# [CV]  n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae, total=   1.6s
# [CV] n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae
# [CV]  n_estimators=1000, min_samples_split=20, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mae, total=   1.6s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse, total=   1.0s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse, total=   1.1s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse, total=   1.1s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse, total=   1.0s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=5, max_features=auto, max_depth=10, criterion=mse, total=   1.1s
# [CV] n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse
# [CV]  n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse, total=   1.3s
# [CV] n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse
# [CV]  n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse, total=   1.2s
# [CV] n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse
# [CV]  n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse, total=   1.1s
# [CV] n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse
# [CV]  n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse, total=   1.1s
# [CV] n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse
# [CV]  n_estimators=1000, min_samples_split=50, min_samples_leaf=1, max_features=log2, max_depth=50, criterion=mse, total=   1.1s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse, total=   1.0s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=1, max_features=log2, max_depth=20, criterion=mse, total=   1.1s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   47.6s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    param_distributions={'criterion': ['mse', 'mae'],
#                                         'max_depth': [10, 20, 30, 40, 50],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 20, 50],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='neg_mean_absolute_error',
#                    verbose=2)

# %%
random_forest.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=5,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
random_forest.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 10,
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 2,
#  'n_estimators': 800}

# %%
random_forest.best_score_
# Out:
# -0.8243475387097664

# %% [markdown]
# # Part 4: Final model (Random forest)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=10, max_features='auto', max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=5,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=800, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=5,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=800, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred = regressor_rf.predict(x_test)

# %%
# R^2 (coefficient of determination) regression score function
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8920438443227852

# %% [markdown]
# # Part 5: Predict charges for a car

# %%
dataset.head()
# Out:
#    Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0           3.35           5.59  ...                       0                    1
# 1           4.75           9.54  ...                       0                    1
# 2           7.25           9.85  ...                       0                    1
# 3           2.85           4.15  ...                       0                    1
# 4           4.60           6.87  ...                       0                    1
#
# [5 rows x 9 columns]

# %%
single_obs = [[9.54, 3500, 0, 4, 1, 0, 0, 1]]

# %%
new_pred = regressor.predict(single_obs)

# %%
print(' The predicted selling price for the car is: {} '.format(new_pred))
# Out:
#  The predicted selling price for the car is: [8.08010645]
